# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/home/shouko/Desktop/ML/data/df_final_features.csv')

# %%
df.sample(5)
# Out:
#                                    Name Sex   Age  Height  Weight  \
# 122955                 Omar Moussa Bouh   M  27.0   163.0    53.0
# 19439                        Dezs Bordn   M  25.0   174.0    65.0
# 20080                      Detlef Bothe   M  18.0   169.0    75.0
# 17966          Sarah "Sally" Bloomfield   F  28.0   168.0    67.0
# 39485   William Javier Delgado Cerquera   M  21.0   157.0    48.0
#
#                   Team  Year  Season    Host_City               Host_Country  \
# 122955        Djibouti  1988  Summer        Seoul  Korea, Dem. People’s Rep.
# 19439          Hungary  1968  Summer  Mexico City                     Mexico
# 20080          Germany  1976  Summer     Montreal                     Canada
# 17966   United Kingdom  1984  Summer  Los Angeles              United States
# 39485         Colombia  1988  Summer        Seoul  Korea, Dem. People’s Rep.
#
#         ... GDP_Per_Capita_Constant_LCU_Value  \
# 122955  ...                      2.625584e+05
# 19439   ...                      1.840746e+06
# 20080   ...                      1.749217e+04
# 17966   ...                      1.523924e+04
# 39485   ...                      9.289605e+06
#
#        Cereal_yield_kg_per_hectare_Value  \
# 122955                            1538.5
# 19439                             2576.3
# 20080                             3495.7
# 17966                             6590.9
# 39485                             2514.4
#
#         Military_expenditure_current_LCU_Value  Tax_revenue_current_LCU_Value  \
# 122955                            5.520000e+09                   1.274950e+12
# 19439                             9.010000e+09                   2.858000e+11
# 20080                             1.990000e+10                   6.805295e+10
# 17966                             1.709075e+10                   8.596500e+10
# 39485                             2.580000e+11                   1.930770e+13
#
#         Expense_current_LCU_Value  \
# 122955               2.373240e+12
# 19439                4.151000e+11
# 20080                1.648870e+11
# 17966                1.277440e+11
# 39485                2.713660e+13
#
#         Central_government_debt_total_current_LCU_Value  Representing_Host  \
# 122955                                     4.448490e+12                  0
# 19439                                      1.850000e+12                  0
# 20080                                      3.063350e+11                  0
# 17966                                      1.859540e+11                  0
# 39485                                      7.591600e+12                  0
#
#         Avg_Temp  Medal Medal_Binary
# 122955        28      0            0
# 19439       9.75      0            0
# 20080        8.5      0            0
# 17966       8.45      0            0
# 39485       24.5      0            0
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Name                                               0
# Sex                                                0
# Age                                                0
# Height                                             1
# Weight                                             1
# Team                                               0
# Year                                               0
# Season                                             0
# Host_City                                          0
# Host_Country                                       0
# Sport                                              0
# Event                                              0
# GDP_Per_Capita_Constant_LCU_Value                  0
# Cereal_yield_kg_per_hectare_Value                  0
# Military_expenditure_current_LCU_Value             0
# Tax_revenue_current_LCU_Value                      0
# Expense_current_LCU_Value                          0
# Central_government_debt_total_current_LCU_Value    0
# Representing_Host                                  0
# Avg_Temp                                           0
# Medal                                              0
# Medal_Binary                                       0
# dtype: int64

# %%
sns.scatterplot(x ='Height',y='Weight',data= df)
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.distplot(df['Height'])
# Out:
# /tmp/ipykernel_6368/3945773010.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.distplot(df['Weight'])
# Out:
# /tmp/ipykernel_6368/1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>
